# %% [markdown]
# # Analytics for Keyword Expansion
#
# Let's imagine we are sitting in the marketing department of a company selling jewelry. We need to plan a campaign with some corner points:
# - it should be running on Facebook Ads
# - it should be approximately a month long
# - we should spend ballpark 500 USD on it daily
# - the ad creative is not perfectly set, but should be centered around the term "embrace your individuality"
#
# Now, we have to find keywords to target the ad with.
#
# In order to do that, we have past campaign data at our disposal. In this notebook the aim is to showcase how to drill through the data effectively to help our efforts finding the best keywords.

# %%
# %pip install superlinked==22.3.0
# %pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting superlinked==22.3.0
#   Downloading superlinked-22.3.0-py3-none-any.whl.metadata (14 kB)
# Collecting Deprecated<2.0.0,>=1.2.18 (from superlinked==22.3.0)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting aiohttp<4.0.0,>=3.11.7 (from superlinked==22.3.0)
#   Downloading aiohttp-3.11.14-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Collecting asgi-correlation-id<5.0.0,>=4.3.4 (from superlinked==22.3.0)
#   Downloading asgi_correlation_id-4.3.4-py3-none-any.whl.metadata (28 kB)
# Collecting beartype<0.20.0,>=0.17.2 (from superlinked==22.3.0)
#   Downloading beartype-0.19.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: cachetools<6.0,>=5.4 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (5.5.0)
# Collecting certifi<2026.0.0,>=2024.7.4 (from superlinked==22.3.0)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: filelock<4.0.0,>=3.16.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (3.16.1)
# Collecting furl<3.0.0,>=2.1.3 (from superlinked==22.3.0)
#   Downloading furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Collecting graphviz<0.21.0,>=0.20.1 (from superlinked==22.3.0)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting instructor<2.0.0,>=1.3.7 (from superlinked==22.3.0)
#   Downloading instructor-1.7.7-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (3.1.4)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (3.9.1)
# Requirement already satisfied: numpy<2.0.0,>=1.25.2 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (1.26.4)
# Collecting open_clip_torch<2.32.0 (from superlinked==22.3.0)
#   Downloading open_clip_torch-2.31.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (2.9.2)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from superlinked==22.3.0)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting redisvl<0.5.0,>=0.4.1 (from superlinked==22.3.0)
#   Downloading redisvl-0.4.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests<3.0,>=2.31 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (2.32.2)
# Collecting sentence-transformers==3.4.1 (from superlinked==22.3.0)
#   Downloading sentence_transformers-3.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting structlog<26.0,>=24.4 (from superlinked==22.3.0)
#   Downloading structlog-25.2.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting types-Deprecated>=1.2.15 (from superlinked==22.3.0)
#   Downloading types_deprecated-1.2.15.20250304-py3-none-any.whl.metadata (2.0 kB)
# Collecting types-cachetools<6.0,>=5.4 (from superlinked==22.3.0)
#   Downloading types_cachetools-5.5.0.20240820-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: typing_extensions>=3.10.0.2 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from superlinked==22.3.0) (4.12.2)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers==3.4.1->superlinked==22.3.0)
#   Downloading transformers-4.50.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: tqdm in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers==3.4.1->superlinked==22.3.0) (4.67.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers==3.4.1->superlinked==22.3.0) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers==3.4.1->superlinked==22.3.0) (1.5.0)
# Requirement already satisfied: scipy in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers==3.4.1->superlinked==22.3.0) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers==3.4.1->superlinked==22.3.0) (0.26.2)
# Requirement already satisfied: Pillow in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers==3.4.1->superlinked==22.3.0) (10.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.11.7->superlinked==22.3.0) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.11.7->superlinked==22.3.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.11.7->superlinked==22.3.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.11.7->superlinked==22.3.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.11.7->superlinked==22.3.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.11.7->superlinked==22.3.0) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.11.7->superlinked==22.3.0) (1.17.2)
# Requirement already satisfied: packaging in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from asgi-correlation-id<5.0.0,>=4.3.4->superlinked==22.3.0) (24.2)
# Requirement already satisfied: starlette>=0.18 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from asgi-correlation-id<5.0.0,>=4.3.4->superlinked==22.3.0) (0.41.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from Deprecated<2.0.0,>=1.2.18->superlinked==22.3.0) (1.16.0)
# Requirement already satisfied: six>=1.8.0 in c:\users\prade\appdata\roaming\python\python311\site-packages (from furl<3.0.0,>=2.1.3->superlinked==22.3.0) (1.16.0)
# Collecting orderedmultidict>=1.0.1 (from furl<3.0.0,>=2.1.3->superlinked==22.3.0)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting docstring-parser<1.0,>=0.16 (from instructor<2.0.0,>=1.3.7->superlinked==22.3.0)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting jiter<0.9,>=0.6.1 (from instructor<2.0.0,>=1.3.7->superlinked==22.3.0)
#   Downloading jiter-0.8.2-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting openai<2.0.0,>=1.52.0 (from instructor<2.0.0,>=1.3.7->superlinked==22.3.0)
#   Downloading openai-1.68.2-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (2.23.4)
# Collecting requests<3.0,>=2.31 (from superlinked==22.3.0)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (13.9.4)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (9.0.0)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (0.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from jinja2<4.0.0,>=3.1.4->superlinked==22.3.0) (2.1.5)
# Requirement already satisfied: click in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from nltk<4.0.0,>=3.9.1->superlinked==22.3.0) (8.1.7)
# Requirement already satisfied: joblib in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from nltk<4.0.0,>=3.9.1->superlinked==22.3.0) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from nltk<4.0.0,>=3.9.1->superlinked==22.3.0) (2024.11.6)
# Collecting torchvision (from open_clip_torch<2.32.0->superlinked==22.3.0)
#   Downloading torchvision-0.21.0-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting ftfy (from open_clip_torch<2.32.0->superlinked==22.3.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: safetensors in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from open_clip_torch<2.32.0->superlinked==22.3.0) (0.4.5)
# Collecting timm (from open_clip_torch<2.32.0->superlinked==22.3.0)
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
#      ---------------------------------------- 0.0/52.0 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.0 kB ? eta -:--:--
#      -------------------------------------- 52.0/52.0 kB 889.1 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prade\appdata\roaming\python\python311\site-packages (from pandas<3.0.0,>=2.0.3->superlinked==22.3.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.0.3->superlinked==22.3.0) (2022.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.0.3->superlinked==22.3.0) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.6.4->superlinked==22.3.0) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->superlinked==22.3.0) (1.0.1)
# Requirement already satisfied: coloredlogs<16.0,>=15.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from redisvl<0.5.0,>=0.4.1->superlinked==22.3.0) (15.0.1)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from redisvl<0.5.0,>=0.4.1->superlinked==22.3.0)
#   Downloading ml_dtypes-0.4.1-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting python-ulid<4.0.0,>=3.0.0 (from redisvl<0.5.0,>=0.4.1->superlinked==22.3.0)
#   Downloading python_ulid-3.0.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.4 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from redisvl<0.5.0,>=0.4.1->superlinked==22.3.0) (6.0.1)
# Collecting redis<6.0,>=5.0 (from redisvl<0.5.0,>=0.4.1->superlinked==22.3.0)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Collecting tabulate<0.10.0,>=0.9.0 (from redisvl<0.5.0,>=0.4.1->superlinked==22.3.0)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.31->superlinked==22.3.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.31->superlinked==22.3.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.31->superlinked==22.3.0) (1.26.13)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs<16.0,>=15.0->redisvl<0.5.0,>=0.4.1->superlinked==22.3.0) (10.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1->superlinked==22.3.0) (2024.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.52.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.52.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.52.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.52.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (1.3.1)
# Collecting async-timeout>=4.0.3 (from redis<6.0,>=5.0->redisvl<0.5.0,>=0.4.1->superlinked==22.3.0)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from rich<14.0.0,>=13.7.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\prade\appdata\roaming\python\python311\site-packages (from rich<14.0.0,>=13.7.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (2.13.0)
# Requirement already satisfied: networkx in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers==3.4.1->superlinked==22.3.0) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers==3.4.1->superlinked==22.3.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers==3.4.1->superlinked==22.3.0) (1.3.0)
# Requirement already satisfied: colorama in c:\users\prade\appdata\roaming\python\python311\site-packages (from tqdm->sentence-transformers==3.4.1->superlinked==22.3.0) (0.4.6)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers==3.4.1->superlinked==22.3.0)
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.9.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (1.5.4)
# Requirement already satisfied: wcwidth in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from ftfy->open_clip_torch<2.32.0->superlinked==22.3.0) (0.2.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers==3.4.1->superlinked==22.3.0) (3.1.0)
# Collecting torch>=1.11.0 (from sentence-transformers==3.4.1->superlinked==22.3.0)
#   Downloading torch-2.6.0-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: httpcore==1.* in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (0.14.0)
# Requirement already satisfied: pyreadline3 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs<16.0,>=15.0->redisvl<0.5.0,>=0.4.1->superlinked==22.3.0) (3.5.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->instructor<2.0.0,>=1.3.7->superlinked==22.3.0) (0.1.2)
# Downloading superlinked-22.3.0-py3-none-any.whl (520 kB)
#    ---------------------------------------- 0.0/520.3 kB ? eta -:--:--
#    ---------- ----------------------------- 133.1/520.3 kB 3.8 MB/s eta 0:00:01
#    -------------------- ------------------- 266.2/520.3 kB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 430.1/520.3 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 520.3/520.3 kB 3.2 MB/s eta 0:00:00
# Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
#    ---------------------------------------- 0.0/275.9 kB ? eta -:--:--
#    ------------------- -------------------- 133.1/275.9 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 275.9/275.9 kB 2.8 MB/s eta 0:00:00
# Downloading aiohttp-3.11.14-cp311-cp311-win_amd64.whl (443 kB)
#    ---------------------------------------- 0.0/443.6 kB ? eta -:--:--
#    ------------ --------------------------- 133.1/443.6 kB 4.0 MB/s eta 0:00:01
#    -------------------------- ------------- 297.0/443.6 kB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 409.6/443.6 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 443.6/443.6 kB 2.8 MB/s eta 0:00:00
# Downloading asgi_correlation_id-4.3.4-py3-none-any.whl (15 kB)
# Downloading beartype-0.19.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.0 MB 4.5 MB/s eta 0:00:01
#    -------- ------------------------------- 0.2/1.0 MB 3.3 MB/s eta 0:00:01
#    ------------- -------------------------- 0.3/1.0 MB 3.1 MB/s eta 0:00:01
#    ------------------ --------------------- 0.5/1.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------ --------------- 0.6/1.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 0.9/1.0 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.0 MB/s eta 0:00:00
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    ----------------------------- ---------- 122.9/166.4 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 166.4/166.4 kB 3.3 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    ---------------------------------------- 47.1/47.1 kB 2.5 MB/s eta 0:00:00
# Downloading instructor-1.7.7-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.9 kB ? eta -:--:--
#    ---------------------------------------- 83.9/83.9 kB 4.9 MB/s eta 0:00:00
# Downloading open_clip_torch-2.31.0-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.5 MB 2.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.5 MB 2.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.4/1.5 MB 3.3 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.5 MB 3.3 MB/s eta 0:00:01
#    ------------------ --------------------- 0.7/1.5 MB 2.9 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 3.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.5 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.1/1.5 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.5 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.5 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 2.9 MB/s eta 0:00:00
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading redisvl-0.4.1-py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.5 kB ? eta -:--:--
#    ---------------------------------------- 108.5/108.5 kB 2.1 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading structlog-25.2.0-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.4 kB ? eta -:--:--
#    ---------------------------------------- 68.4/68.4 kB 3.6 MB/s eta 0:00:00
# Downloading types_cachetools-5.5.0.20240820-py3-none-any.whl (4.1 kB)
# Downloading types_deprecated-1.2.15.20250304-py3-none-any.whl (8.6 kB)
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading jiter-0.8.2-cp311-cp311-win_amd64.whl (206 kB)
#    ---------------------------------------- 0.0/206.7 kB ? eta -:--:--
#    ---------------------------------------  204.8/206.7 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 206.7/206.7 kB 4.3 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.1-cp311-cp311-win_amd64.whl (126 kB)
#    ---------------------------------------- 0.0/126.7 kB ? eta -:--:--
#    ---------------------------------------- 126.7/126.7 kB 7.3 MB/s eta 0:00:00
# Downloading openai-1.68.2-py3-none-any.whl (606 kB)
#    ---------------------------------------- 0.0/606.1 kB ? eta -:--:--
#    --------------- ------------------------ 235.5/606.1 kB 4.8 MB/s eta 0:00:01
#    ------------------------------- -------- 481.3/606.1 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 606.1/606.1 kB 4.8 MB/s eta 0:00:00
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Downloading python_ulid-3.0.0-py3-none-any.whl (11 kB)
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
#    ---------------------------------------- 0.0/261.5 kB ? eta -:--:--
#    ---------------------------------------  256.0/261.5 kB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 261.5/261.5 kB 5.3 MB/s eta 0:00:00
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading transformers-4.50.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.2 MB 5.0 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/10.2 MB 5.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/10.2 MB 4.3 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/10.2 MB 3.9 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/10.2 MB 3.7 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/10.2 MB 3.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/10.2 MB 3.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/10.2 MB 3.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/10.2 MB 3.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/10.2 MB 3.3 MB/s eta 0:00:03
#    ------ --------------------------------- 1.7/10.2 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/10.2 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.9/10.2 MB 3.2 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/10.2 MB 3.2 MB/s eta 0:00:03
#    -------- ------------------------------- 2.2/10.2 MB 3.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/10.2 MB 3.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.5/10.2 MB 3.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/10.2 MB 3.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.8/10.2 MB 3.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.9/10.2 MB 3.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/10.2 MB 3.1 MB/s eta 0:00:03
#    ------------ --------------------------- 3.2/10.2 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 3.3/10.2 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 3.5/10.2 MB 3.1 MB/s eta 0:00:03
#    -------------- ------------------------- 3.6/10.2 MB 3.1 MB/s eta 0:00:03
#    -------------- ------------------------- 3.8/10.2 MB 3.2 MB/s eta 0:00:03
#    --------------- ------------------------ 3.9/10.2 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 4.0/10.2 MB 3.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.2 MB 3.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.3/10.2 MB 3.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.2 MB 3.1 MB/s eta 0:00:02
#    ------------------ --------------------- 4.6/10.2 MB 3.1 MB/s eta 0:00:02
#    ------------------ --------------------- 4.7/10.2 MB 3.1 MB/s eta 0:00:02
#    ------------------- -------------------- 4.9/10.2 MB 3.1 MB/s eta 0:00:02
#    ------------------- -------------------- 5.0/10.2 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 5.2/10.2 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 5.3/10.2 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.5/10.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.6/10.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.8/10.2 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.9/10.2 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.0/10.2 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.2/10.2 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.3/10.2 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.5/10.2 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.6/10.2 MB 3.1 MB/s eta 0:00:02
#    -------------------------- ------------- 6.8/10.2 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 6.9/10.2 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 7.0/10.2 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 7.1/10.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.2/10.2 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.4/10.2 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.6/10.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.8/10.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/10.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.2 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.2/10.2 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.3/10.2 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.5/10.2 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.6/10.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.8/10.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.9/10.2 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.1/10.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.3/10.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.5/10.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.6/10.2 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.8/10.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  9.9/10.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  10.1/10.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  10.2/10.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 3.1 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.8 kB ? eta -:--:--
#    ---------------------------------------- 44.8/44.8 kB 2.2 MB/s eta 0:00:00
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.4 MB 7.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.4 MB 5.5 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.4 MB 5.2 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.4 MB 4.6 MB/s eta 0:00:01
#    -------------- ------------------------- 0.9/2.4 MB 4.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.4 MB 4.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------ --------------- 1.5/2.4 MB 3.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.4 MB 3.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.4 MB 3.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.9/2.4 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.0/2.4 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 2.2/2.4 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.4 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 3.2 MB/s eta 0:00:00
# Downloading torchvision-0.21.0-cp311-cp311-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.6 MB 5.9 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.6 MB 6.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.6 MB 4.9 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 4.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.9/1.6 MB 4.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.1/1.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.6 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 1.5/1.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.5 MB/s eta 0:00:00
# Downloading torch-2.6.0-cp311-cp311-win_amd64.whl (204.2 MB)
#    ---------------------------------------- 0.0/204.2 MB ? eta -:--:--
#    ---------------------------------------- 0.2/204.2 MB 6.7 MB/s eta 0:00:31
#    ---------------------------------------- 0.4/204.2 MB 4.5 MB/s eta 0:00:45
#    ---------------------------------------- 0.5/204.2 MB 4.2 MB/s eta 0:00:49
#    ---------------------------------------- 0.7/204.2 MB 3.8 MB/s eta 0:00:54
#    ---------------------------------------- 0.8/204.2 MB 3.6 MB/s eta 0:00:56
#    ---------------------------------------- 0.9/204.2 MB 3.5 MB/s eta 0:00:59
#    ---------------------------------------- 1.1/204.2 MB 3.5 MB/s eta 0:00:59
#    ---------------------------------------- 1.2/204.2 MB 3.4 MB/s eta 0:01:00
#    ---------------------------------------- 1.4/204.2 MB 3.4 MB/s eta 0:01:01
#    ---------------------------------------- 1.5/204.2 MB 3.4 MB/s eta 0:00:59
#    ---------------------------------------- 1.7/204.2 MB 3.3 MB/s eta 0:01:01
#    ---------------------------------------- 1.8/204.2 MB 3.3 MB/s eta 0:01:01
#    ---------------------------------------- 2.0/204.2 MB 3.4 MB/s eta 0:01:01
#    ---------------------------------------- 2.1/204.2 MB 3.4 MB/s eta 0:01:01
#    ---------------------------------------- 2.3/204.2 MB 3.3 MB/s eta 0:01:01
#    ---------------------------------------- 2.4/204.2 MB 3.3 MB/s eta 0:01:01
#    ---------------------------------------- 2.5/204.2 MB 3.3 MB/s eta 0:01:01
#     --------------------------------------- 2.7/204.2 MB 3.3 MB/s eta 0:01:02
#     --------------------------------------- 2.8/204.2 MB 3.3 MB/s eta 0:01:02
#     --------------------------------------- 2.9/204.2 MB 3.3 MB/s eta 0:01:02
#     --------------------------------------- 3.1/204.2 MB 3.3 MB/s eta 0:01:02
#     --------------------------------------- 3.3/204.2 MB 3.3 MB/s eta 0:01:02
#     --------------------------------------- 3.4/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 3.5/204.2 MB 3.2 MB/s eta 0:01:02
#     --------------------------------------- 3.7/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 3.8/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 4.0/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 4.1/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 4.2/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 4.4/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 4.5/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 4.7/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 4.8/204.2 MB 3.2 MB/s eta 0:01:03
#     --------------------------------------- 5.0/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 5.1/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 5.3/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 5.4/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 5.5/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 5.7/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 5.8/204.2 MB 3.1 MB/s eta 0:01:04
#    - -------------------------------------- 5.9/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 6.1/204.2 MB 3.1 MB/s eta 0:01:04
#    - -------------------------------------- 6.1/204.2 MB 3.1 MB/s eta 0:01:04
#    - -------------------------------------- 6.3/204.2 MB 3.1 MB/s eta 0:01:04
#    - -------------------------------------- 6.5/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 6.7/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 6.8/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 7.0/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 7.1/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 7.3/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 7.4/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 7.6/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 7.7/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 7.9/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 7.9/204.2 MB 3.1 MB/s eta 0:01:03
#    - -------------------------------------- 8.2/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 8.3/204.2 MB 3.2 MB/s eta 0:01:02
#    - -------------------------------------- 8.4/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 8.6/204.2 MB 3.2 MB/s eta 0:01:03
#    - -------------------------------------- 8.7/204.2 MB 3.1 MB/s eta 0:01:03
#    - -------------------------------------- 8.9/204.2 MB 3.2 MB/s eta 0:01:02
#    - -------------------------------------- 9.0/204.2 MB 3.1 MB/s eta 0:01:03
#    - -------------------------------------- 9.1/204.2 MB 3.2 MB/s eta 0:01:02
#    - -------------------------------------- 9.3/204.2 MB 3.2 MB/s eta 0:01:02
#    - -------------------------------------- 9.4/204.2 MB 3.2 MB/s eta 0:01:02
#    - -------------------------------------- 9.6/204.2 MB 3.2 MB/s eta 0:01:02
#    - -------------------------------------- 9.7/204.2 MB 3.1 MB/s eta 0:01:02
#    - -------------------------------------- 9.8/204.2 MB 3.1 MB/s eta 0:01:02
#    - -------------------------------------- 10.0/204.2 MB 3.1 MB/s eta 0:01:02
#    - -------------------------------------- 10.1/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 10.3/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 10.4/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 10.6/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 10.7/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 10.8/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 11.0/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 11.1/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 11.3/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 11.4/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 11.5/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 11.7/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 11.8/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 12.0/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 12.1/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 12.2/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 12.4/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 12.5/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 12.7/204.2 MB 3.1 MB/s eta 0:01:03
#    -- ------------------------------------- 12.8/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 13.0/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 13.1/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 13.3/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 13.4/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 13.6/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 13.7/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 13.9/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 14.0/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 14.2/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 14.3/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 14.4/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 14.6/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 14.7/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 14.9/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 15.0/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 15.0/204.2 MB 3.1 MB/s eta 0:01:02
#    -- ------------------------------------- 15.3/204.2 MB 3.1 MB/s eta 0:01:02
#    --- ------------------------------------ 15.4/204.2 MB 3.1 MB/s eta 0:01:02
#    --- ------------------------------------ 15.6/204.2 MB 3.1 MB/s eta 0:01:02
#    --- ------------------------------------ 15.7/204.2 MB 3.1 MB/s eta 0:01:02
#    --- ------------------------------------ 15.9/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 16.0/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 16.2/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 16.3/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 16.4/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 16.6/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 16.7/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 16.9/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 17.0/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 17.2/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 17.3/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 17.5/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 17.6/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 17.8/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 17.9/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 18.1/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 18.2/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 18.4/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 18.5/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 18.6/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 18.7/204.2 MB 3.1 MB/s eta 0:01:01
#    --- ------------------------------------ 18.9/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 19.0/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 19.2/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 19.3/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 19.5/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 19.6/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 19.8/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 19.9/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 20.1/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 20.2/204.2 MB 3.1 MB/s eta 0:01:00
#    --- ------------------------------------ 20.4/204.2 MB 3.1 MB/s eta 0:01:00
#    ---- ----------------------------------- 20.5/204.2 MB 3.1 MB/s eta 0:01:00
#    ---- ----------------------------------- 20.7/204.2 MB 3.1 MB/s eta 0:01:00
#    ---- ----------------------------------- 20.8/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 21.0/204.2 MB 3.1 MB/s eta 0:01:00
#    ---- ----------------------------------- 21.1/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 21.2/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 21.4/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 21.5/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 21.7/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 21.8/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 21.9/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 22.1/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 22.2/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 22.4/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 22.5/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 22.7/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 22.8/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 23.0/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 23.1/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 23.2/204.2 MB 3.1 MB/s eta 0:00:59
#    ---- ----------------------------------- 23.4/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 23.5/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 23.7/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 23.8/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 24.0/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 24.1/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 24.3/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 24.4/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 24.6/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 24.7/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 24.8/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 25.0/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 25.1/204.2 MB 3.1 MB/s eta 0:00:58
#    ---- ----------------------------------- 25.3/204.2 MB 3.2 MB/s eta 0:00:57
#    ---- ----------------------------------- 25.4/204.2 MB 3.1 MB/s eta 0:00:58
#    ----- ---------------------------------- 25.6/204.2 MB 3.1 MB/s eta 0:00:58
#    ----- ---------------------------------- 25.7/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 25.8/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 26.0/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 26.1/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 26.3/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 26.4/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 26.6/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 26.7/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 26.8/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 27.0/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 27.1/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 27.3/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 27.4/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 27.6/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 27.7/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 27.9/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 28.0/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 28.2/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 28.2/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 28.4/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 28.6/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 28.7/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 28.9/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 29.0/204.2 MB 3.1 MB/s eta 0:00:57
#    ----- ---------------------------------- 29.2/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 29.3/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 29.4/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 29.6/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 29.7/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 29.9/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 30.0/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 30.2/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 30.3/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 30.5/204.2 MB 3.1 MB/s eta 0:00:56
#    ----- ---------------------------------- 30.6/204.2 MB 3.1 MB/s eta 0:00:56
#    ------ --------------------------------- 30.7/204.2 MB 3.1 MB/s eta 0:00:56
# ...
#    ------------------------------------ --- 186.3/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 186.5/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 186.6/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 186.7/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 186.9/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 186.9/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 187.2/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 187.3/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 187.5/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 187.6/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 187.7/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 187.9/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 188.0/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 188.2/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 188.3/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 188.5/204.2 MB 3.1 MB/s eta 0:00:06
#    ------------------------------------ --- 188.6/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------ --- 188.8/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 188.9/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 189.1/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 189.2/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 189.4/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 189.5/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 189.6/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 189.8/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 189.9/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 190.1/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 190.2/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 190.4/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 190.5/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 190.6/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 190.8/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 190.9/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 191.1/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 191.2/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 191.4/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 191.5/204.2 MB 3.1 MB/s eta 0:00:05
#    ------------------------------------- -- 191.7/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 191.8/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 191.9/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 192.1/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 192.2/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 192.3/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 192.5/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 192.7/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 192.8/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 193.0/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 193.1/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 193.3/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 193.4/204.2 MB 3.2 MB/s eta 0:00:04
#    ------------------------------------- -- 193.5/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 193.7/204.2 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 193.8/204.2 MB 3.1 MB/s eta 0:00:04
#    -------------------------------------- - 194.0/204.2 MB 3.1 MB/s eta 0:00:04
#    -------------------------------------- - 194.1/204.2 MB 3.1 MB/s eta 0:00:04
#    -------------------------------------- - 194.3/204.2 MB 3.1 MB/s eta 0:00:04
#    -------------------------------------- - 194.4/204.2 MB 3.1 MB/s eta 0:00:04
#    -------------------------------------- - 194.5/204.2 MB 3.1 MB/s eta 0:00:04
#    -------------------------------------- - 194.7/204.2 MB 3.1 MB/s eta 0:00:04
#    -------------------------------------- - 194.8/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 195.0/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 195.1/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 195.3/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 195.4/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 195.6/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 195.7/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 195.9/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 196.0/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 196.2/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 196.3/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 196.4/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 196.6/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 196.7/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 196.9/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 197.0/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 197.2/204.2 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 197.3/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 197.4/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 197.6/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 197.7/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 197.9/204.2 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 198.0/204.2 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 198.2/204.2 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 198.3/204.2 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 198.5/204.2 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 198.6/204.2 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 198.7/204.2 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 198.9/204.2 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 199.0/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  199.2/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  199.3/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  199.5/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  199.6/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  199.7/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  199.9/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  200.0/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  200.1/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  200.3/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  200.4/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  200.5/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  200.6/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  200.8/204.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  201.1/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  201.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  201.3/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  201.5/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  201.6/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  201.8/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  201.9/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  202.1/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  202.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  202.4/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  202.5/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  202.6/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  202.8/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  202.9/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  203.0/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  203.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  203.4/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  203.5/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  203.7/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  203.8/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.0/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.1/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  204.2/204.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 204.2/204.2 MB 2.8 MB/s eta 0:00:00
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/2.4 MB 7.0 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.4 MB 6.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.7/2.4 MB 5.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.4 MB 4.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.4 MB 4.5 MB/s eta 0:00:01
#    ------------------ --------------------- 1.1/2.4 MB 4.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.4 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.4/2.4 MB 3.9 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.4 MB 3.8 MB/s eta 0:00:01
#    --------------------------- ------------ 1.7/2.4 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.9/2.4 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 2.0/2.4 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.3/2.4 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 3.4 MB/s eta 0:00:00
# Installing collected packages: types-Deprecated, types-cachetools, tabulate, structlog, python-ulid, orderedmultidict, ml-dtypes, jiter, graphviz, ftfy, docstring-parser, Deprecated, certifi, beartype, async-timeout, torch, requests, redis, furl, aiohttp, torchvision, redisvl, pydantic-settings, asgi-correlation-id, tokenizers, timm, openai, transformers, open_clip_torch, instructor, sentence-transformers, superlinked
#   Attempting uninstall: Deprecated
#     Found existing installation: Deprecated 1.2.15
#     Uninstalling Deprecated-1.2.15:
#       Successfully uninstalled Deprecated-1.2.15
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.9.24
#     Uninstalling certifi-2022.9.24:
#       Successfully uninstalled certifi-2022.9.24
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.2
#     Uninstalling requests-2.32.2:
#       Successfully uninstalled requests-2.32.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.6
#     Uninstalling aiohttp-3.11.6:
#       Successfully uninstalled aiohttp-3.11.6
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
# Successfully installed Deprecated-1.2.18 aiohttp-3.11.14 asgi-correlation-id-4.3.4 async-timeout-5.0.1 beartype-0.19.0 certifi-2025.1.31 docstring-parser-0.16 ftfy-6.3.1 furl-2.1.4 graphviz-0.20.3 instructor-1.7.7 jiter-0.8.2 ml-dtypes-0.4.1 open_clip_torch-2.31.0 openai-1.68.2 orderedmultidict-1.0.1 pydantic-settings-2.8.1 python-ulid-3.0.0 redis-5.2.1 redisvl-0.4.1 requests-2.32.3 sentence-transformers-3.4.1 structlog-25.2.0 superlinked-22.3.0 tabulate-0.9.0 timm-1.0.15 tokenizers-0.21.1 torch-2.6.0 torchvision-0.21.0 transformers-4.50.0 types-Deprecated-1.2.15.20250304 types-cachetools-5.5.0.20240820
# Requirement already satisfied: matplotlib in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (3.9.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.52.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prade\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prade\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\prade\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datetime import datetime, timedelta
import os
import sys
import warnings
import altair as alt
import pandas as pd
from superlinked import framework as sl

alt.data_transformers.disable_max_rows()
alt.renderers.enable(sl.get_altair_renderer())
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:.3f}")
# silence torch warning from sentence_transformers
warnings.filterwarnings("ignore", category=UserWarning, message="TypedStorage is deprecated")

END_OF_2022_12_10_TS = int(datetime(2022, 12, 11).timestamp())
EXECUTOR_DATA = {sl.CONTEXT_COMMON: {sl.CONTEXT_COMMON_NOW: END_OF_2022_12_10_TS}}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import altair as alt
#       6 import pandas as pd
# ----> 7 from superlinked import framework as sl
#       9 alt.data_transformers.disable_max_rows()
#      10 alt.renderers.enable(sl.get_altair_renderer())
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\__init__.py:46
#      44     pass
#      45 from superlinked.evaluation.pandas_converter import PandasConverter
# ---> 46 from superlinked.evaluation.vector_sampler import VectorSampler
#      47 from superlinked.framework.blob.blob_handler_factory import BlobHandlerConfig
#      48 from superlinked.framework.common.dag.context import CONTEXT_COMMON, CONTEXT_COMMON_NOW
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\evaluation\vector_sampler.py:22
#      20 from superlinked.framework.common.schema.schema_object import SchemaObject
#      21 from superlinked.framework.common.storage_manager.header import Header
# ---> 22 from superlinked.framework.dsl.executor.in_memory.in_memory_executor import InMemoryApp
#      23 from superlinked.framework.dsl.index.index import Index
#      24 from superlinked.framework.storage.in_memory.in_memory_vdb import InMemoryVDB
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\dsl\executor\in_memory\in_memory_executor.py:21
#      18 from beartype.typing import Mapping, Sequence
#      20 from superlinked.framework.common.dag.context import ContextValue
# ---> 21 from superlinked.framework.dsl.app.in_memory.in_memory_app import InMemoryApp
#      22 from superlinked.framework.dsl.executor.interactive.interactive_executor import (
#      23     InteractiveExecutor,
#      24 )
#      25 from superlinked.framework.dsl.index.index import Index
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\dsl\app\in_memory\in_memory_app.py:20
#      18 from superlinked.framework.common.dag.context import ExecutionContext
#      19 from superlinked.framework.common.util.type_validator import TypeValidator
# ---> 20 from superlinked.framework.dsl.app.interactive.interactive_app import InteractiveApp
#      21 from superlinked.framework.dsl.index.index import Index
#      22 from superlinked.framework.dsl.source.in_memory_source import InMemorySource
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\dsl\app\interactive\interactive_app.py:20
#      18 from superlinked.framework.common.dag.context import ExecutionContext
#      19 from superlinked.framework.common.util.type_validator import TypeValidator
# ---> 20 from superlinked.framework.dsl.app.online.online_app import OnlineApp
#      21 from superlinked.framework.dsl.index.index import Index
#      22 from superlinked.framework.dsl.source.interactive_source import InteractiveSource
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\dsl\app\online\online_app.py:26
#      24 from superlinked.framework.dsl.app.app import App
#      25 from superlinked.framework.dsl.index.index import Index
# ---> 26 from superlinked.framework.dsl.query.query_mixin import QueryMixin
#      27 from superlinked.framework.dsl.query.query_result_converter.default_query_result_converter import (
#      28     DefaultQueryResultConverter,
#      29 )
#      30 from superlinked.framework.dsl.query.query_result_converter.query_result_converter import (
#      31     QueryResultConverter,
#      32 )
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\dsl\query\query_mixin.py:19
#      17 from superlinked.framework.common.exception import QueryException
#      18 from superlinked.framework.common.util.type_validator import TypeValidator
# ---> 19 from superlinked.framework.dsl.executor.query.query_executor import QueryExecutor
#      20 from superlinked.framework.dsl.index.index import Index
#      21 from superlinked.framework.dsl.query.query_descriptor import QueryDescriptor
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\dsl\executor\query\query_executor.py:50
#      46 from superlinked.framework.dsl.query.query_descriptor import QueryDescriptor
#      47 from superlinked.framework.dsl.query.query_param_value_setter import (
#      48     QueryParamValueSetter,
#      49 )
# ---> 50 from superlinked.framework.dsl.query.query_vector_factory import QueryVectorFactory
#      51 from superlinked.framework.dsl.query.result import (
#      52     QueryResult,
#      53     ResultEntry,
#      54     ResultEntryMetadata,
#      55     ResultMetadata,
#      56 )
#      58 logger = structlog.getLogger()
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\dsl\query\query_vector_factory.py:32
#      28 from superlinked.framework.dsl.space.space import Space
#      29 from superlinked.framework.query.dag.query_index_node import (
#      30     QUERIED_SCHEMA_NAME_CONTEXT_KEY,
#      31 )
# ---> 32 from superlinked.framework.query.query_dag_evaluator import QueryDagEvaluator
#      33 from superlinked.framework.query.query_node_input import QueryNodeInput
#      35 # Exclude from documentation.
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\query\query_dag_evaluator.py:24
#      22 from superlinked.framework.common.dag.dag import Dag
#      23 from superlinked.framework.common.data_types import Vector
# ---> 24 from superlinked.framework.compiler.query.query_dag_compiler import QueryDagCompiler
#      25 from superlinked.framework.query.dag.query_dag import QueryDag
#      26 from superlinked.framework.query.query_node_input import QueryNodeInput
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\compiler\query\query_dag_compiler.py:22
#      20 from superlinked.framework.common.dag.node import Node
#      21 from superlinked.framework.common.dag.schema_field_node import SchemaFieldNode
# ---> 22 from superlinked.framework.compiler.query.query_node_registry import QueryNodeRegistry
#      23 from superlinked.framework.query.dag.query_dag import QueryDag
#      24 from superlinked.framework.query.dag.query_node import QueryNode
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\compiler\query\query_node_registry.py:17
#      15 from superlinked.framework.compiler.compiled_node_registry import CompiledNodeRegistry
#      16 from superlinked.framework.query.dag.query_aggregation_node import QueryAggregationNode
# ---> 17 from superlinked.framework.query.dag.query_categorical_similarity_node import (
#      18     QueryCategoricalSimilarityNode,
#      19 )
#      20 from superlinked.framework.query.dag.query_concatenation_node import (
#      21     QueryConcatenationNode,
#      22 )
#      23 from superlinked.framework.query.dag.query_constant_node import QueryConstantNode
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\query\dag\query_categorical_similarity_node.py:25
#      23 from superlinked.framework.common.data_types import Vector
#      24 from superlinked.framework.common.interface.weighted import Weighted
# ---> 25 from superlinked.framework.query.dag.query_embedding_orphan_node import (
#      26     QueryEmbeddingOrphanNode,
#      27 )
#      28 from superlinked.framework.query.dag.query_node import QueryNode
#      29 from superlinked.framework.query.query_node_input import (
#      30     QueryNodeInput,
#      31     QueryNodeInputValue,
#      32 )
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\query\dag\query_embedding_orphan_node.py:26
#      22 from superlinked.framework.common.dag.node import NodeDataT
#      23 from superlinked.framework.common.space.config.aggregation.aggregation_config import (
#      24     AggregationInputT,
#      25 )
# ---> 26 from superlinked.framework.query.dag.query_embedding_node import QueryEmbeddingNode
#      27 from superlinked.framework.query.dag.query_evaluation_data_types import (
#      28     QueryEvaluationResult,
#      29 )
#      30 from superlinked.framework.query.query_node_input import QueryNodeInput
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\query\dag\query_embedding_node.py:30
#      26 from superlinked.framework.common.interface.weighted import Weighted
#      27 from superlinked.framework.common.space.config.aggregation.aggregation_config import (
#      28     AggregationInputT,
#      29 )
# ---> 30 from superlinked.framework.common.transform.transformation_factory import (
#      31     TransformationFactory,
#      32 )
#      33 from superlinked.framework.query.dag.exception import QueryEvaluationException
#      34 from superlinked.framework.query.dag.query_evaluation_data_types import (
#      35     QueryEvaluationResult,
#      36     QueryEvaluationResultT,
#      37 )
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\common\transform\transformation_factory.py:43
#      36 from superlinked.framework.common.space.config.transformation_config import (
#      37     TransformationConfig,
#      38 )
#      39 from superlinked.framework.common.space.embedding.embedding import (
#      40     Embedding,
#      41     InvertibleEmbedding,
#      42 )
# ---> 43 from superlinked.framework.common.space.embedding.embedding_factory import (
#      44     EmbeddingFactory,
#      45 )
#      46 from superlinked.framework.common.space.embedding.embedding_step import (
#      47     EmbeddingStep,
#      48     InverseMultiEmbeddingStep,
#      49     MultiEmbeddingStep,
#      50 )
#      51 from superlinked.framework.common.space.normalization.normalization import Normalization
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\common\space\embedding\embedding_factory.py:37
#      31 from superlinked.framework.common.space.config.embedding.number_embedding_config import (
#      32     NumberEmbeddingConfig,
#      33 )
#      34 from superlinked.framework.common.space.config.embedding.recency_embedding_config import (
#      35     RecencyEmbeddingConfig,
#      36 )
# ---> 37 from superlinked.framework.common.space.config.embedding.text_similarity_embedding_config import (
#      38     TextSimilarityEmbeddingConfig,
#      39 )
#      40 from superlinked.framework.common.space.embedding.categorical_similarity_embedding import (
#      41     CategoricalSimilarityEmbedding,
#      42 )
#      43 from superlinked.framework.common.space.embedding.custom_embedding import (
#      44     CustomEmbedding,
#      45 )
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\common\space\config\embedding\text_similarity_embedding_config.py:25
#      20 from typing_extensions import override
#      22 from superlinked.framework.common.space.config.embedding.embedding_config import (
#      23     EmbeddingConfig,
#      24 )
# ---> 25 from superlinked.framework.common.space.embedding.hugging_face_manager import (
#      26     HuggingFaceManager,
#      27 )
#      28 from superlinked.framework.common.space.embedding.sentence_transformer_manager import (
#      29     SentenceTransformerManager,
#      30 )
#      33 class TextModelHandler(Enum):
#
# File c:\Users\prade\AppData\Local\Programs\Python\Python311\Lib\site-packages\superlinked\framework\common\space\embedding\hugging_face_manager.py:23
#      21 from beartype.typing import Any, Sequence, cast
#      22 from huggingface_hub import HfApi, InferenceClient
# ---> 23 from huggingface_hub.inference._providers import PROVIDER_T
#      24 from PIL.Image import Image
#      25 from requests import HTTPError
#
# ModuleNotFoundError: No module named 'huggingface_hub.inference._providers'

# %%
def describe_with_percentiles(
    series: pd.Series,
    percentiles: list[float] | None = None,
) -> pd.Series:
    """
    Wrapper around pd.series.describe() giving the percentiles arg a different default.
    """
    if percentiles is None:
        percentiles = [0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99, 0.995]
    return series.describe(percentiles=percentiles)

# %%
DATASET_URL: str = (
    "https://storage.googleapis.com/superlinked-notebook-analytics-keyword-expansion-ads/marketing-dataset-filtered.csv"
)
USE_COLUMNS: list[str] = [
    "time",
    "media_cost_usd",
    "no_of_days",
    "search_tags",
    "keywords",
    "ext_service_name",
    "clicks",
]

# %% [markdown]
# ## Load and clean dataset

# %%
NROWS = int(os.getenv("NOTEBOOK_TEST_ROW_LIMIT", str(sys.maxsize)))
dataset = pd.read_csv(DATASET_URL, nrows=NROWS).reset_index()
dataset.head()
# Out:
#    index  campaign_item_id  no_of_days        time  ext_service_id  \
# 0      0              2733           9  2022-05-03             128
# 1      1              2766          54  2022-06-01               4
# 2      2              2766          55  2022-06-02              16
# 3      3              2766          58  2022-06-05             128
# 4      4              2766          62  2022-06-09             128
#
#   ext_service_name  creative_id  creative_width  creative_height  \
# 0     Facebook Ads         1000         300.000          250.000
# 1       Google Ads         1005           0.000            0.000
# 2            DV360         1005           0.000            0.000
# 3     Facebook Ads         1005           0.000            0.000
# 4     Facebook Ads         1005           0.000            0.000
#
#                               search_tags  template_id  \
# 0      #Embrace Your Individuality with X       90.000
# 1  #The Ultimate Fashion Statement with X       23.000
# 2  #The Ultimate Fashion Statement with X       23.000
# 3      #Embrace Your Individuality with X       23.000
# 4      #Embrace Your Individuality with X       23.000
#
#                                         landing_page  advertiser_id  \
# 0  https://www.abcjewelry.com/collections/boho-je...           4756
# 1  https://www.abcjewelry.com/collections/gemston...           5191
# 2  https://www.abcjewelry.com/collections/stateme...           5191
# 3  https://www.abcjewelry.com/collections/gemston...           5191
# 4  https://www.abcjewelry.com/collections/pendant...           5191
#
#   advertiser_name  network_id  approved_budget advertiser_currency  \
# 0             Web         190          400.000                 SGD
# 1           Brand         287         1000.000                 USD
# 2           Brand         287         1000.000                 USD
# 3           Brand         287         1000.000                 USD
# 4           Brand         287         1000.000                 USD
#
#    channel_id channel_name  max_bid_cpm  network_margin  campaign_budget_usd  \
# 0           8       Social          NaN           0.000              652.174
# 1          32       Mobile        1.000           0.000              760.000
# 2           1      Display        1.000           0.000              760.000
# 3           4       Search        1.000           0.000              760.000
# 4          64        Video        1.000           0.000              760.000
#
#    impressions  clicks stats_currency currency_code  exchange_rate  \
# 0         2135      32            SGD           SGD              1
# 1          876      18            USD           USD              1
# 2          790      12            USD           USD              1
# 3          655      12            USD           USD              1
# 4          622      10            USD           USD              1
#
#    media_cost_usd  position_in_content  unique_reach  total_reach  \
# 0         109.420                  NaN           NaN          NaN
# 1          43.151                  NaN           NaN          NaN
# 2          31.436                  NaN           NaN          NaN
# 3          13.351                  NaN           NaN          NaN
# 4          13.629                  NaN           NaN          NaN
#
#   search_tag_cat cmi_currency_code          timezone weekday_cat  \
# 0         Others               SGD    Asia/Singapore    week_day
# 1        Youtube               USD  America/New_York    week_day
# 2        Youtube               USD  America/New_York    week_day
# 3        Youtube               USD  America/New_York    week_end
# 4        Youtube               USD  America/New_York    week_day
#
#                     keywords
# 0            artisan jewelry
# 1             bridal jewelry
# 2  unique and trendy jewelry
# 3            artisan jewelry
# 4         rhinestone jewelry

# %%
filtered_dataset = dataset.loc[:, USE_COLUMNS].reset_index().copy()
# filtering for campaigns with spending and days info",
filtered_dataset = filtered_dataset[filtered_dataset["no_of_days"] > 0]
filtered_dataset = filtered_dataset[filtered_dataset["media_cost_usd"] > 0]
# calculate and clean",
filtered_dataset["time"] = [int(f.timestamp()) for f in pd.to_datetime(filtered_dataset.loc[:, "time"])]
filtered_dataset["daily_cost"] = filtered_dataset.loc[:, "media_cost_usd"] / filtered_dataset.loc[:, "no_of_days"]
filtered_dataset["daily_click"] = filtered_dataset.loc[:, "clicks"] / filtered_dataset.loc[:, "no_of_days"]
filtered_dataset["cost_per_click"] = filtered_dataset.loc[:, "media_cost_usd"] / filtered_dataset.loc[:, "clicks"]
filtered_dataset.shape
# Out:
# (23886, 11)

# %%
# uncomment this line to run on a smaller sample of data for a lightning fast run
# filtered_dataset = filtered_dataset.sample(2000)

# %% [markdown]
# ## Data exploration
#
# To find the right space parameters.

# %%
pd.to_datetime(filtered_dataset["time"], unit="s").hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# Recency space should have two period times - one for the frequent 2 months, and 8 months to cover the whole span of time campaigns happened.
#
# See other space parameters inline with the corresponding table creation.

# %%
# encode between [0-100] using NumberSpace with Similar mode
# as we might prefer varying campaign lengths based on our preferences
describe_with_percentiles(filtered_dataset["no_of_days"])
# Out:
# count   23886.000
# mean       27.798
# std        25.445
# min         1.000
# 5%          2.000
# 10%         4.000
# 25%         9.000
# 50%        20.000
# 75%        37.000
# 90%        65.000
# 95%        85.000
# 99%       111.150
# 99.5%     115.000
# max       118.000
# Name: no_of_days, dtype: float64

# %%
# very skewed, depends on no_of_days, not embedding it!
describe_with_percentiles(filtered_dataset["clicks"])
# Out:
# count   23886.000
# mean       52.834
# std       365.499
# min         2.000
# 5%          3.000
# 10%         3.000
# 25%         5.000
# 50%         8.000
# 75%        13.000
# 90%        82.000
# 95%       157.000
# 99%       742.150
# 99.5%    1431.675
# max     20644.000
# Name: clicks, dtype: float64

# %%
# encode between [0, 50] outliers would skew the distribution.
# Use NumberSpace with Similar mode as we might have different budgets
describe_with_percentiles(filtered_dataset["daily_cost"])
# Out:
# count   23886.000
# mean        2.067
# std        23.388
# min         0.000
# 5%          0.002
# 10%         0.005
# 25%         0.018
# 50%         0.085
# 75%         0.642
# 90%         3.341
# 95%         6.861
# 99%        29.464
# 99.5%      46.276
# max      2295.029
# Name: daily_cost, dtype: float64

# %%
# encode between [0, 100] outliers would skew the distribution.
# Use NumberSpace with Maximum Mode as we prefer better daily_click bringing campaigns all else being equal
describe_with_percentiles(filtered_dataset["daily_click"])
# Out:
# count   23886.000
# mean        7.773
# std        93.427
# min         0.017
# 5%          0.065
# 10%         0.091
# 25%         0.174
# 50%         0.400
# 75%         1.556
# 90%         9.564
# 95%        22.650
# 99%       107.858
# 99.5%     205.331
# max      8090.000
# Name: daily_click, dtype: float64

# %%
# encode between [0, 2] outliers would skew the distribution.
# Use NumberSpace with Minimum Mode as we prefer campaigns that achieve a click spending less dollars.
# Measured in thousand USD.
describe_with_percentiles(filtered_dataset["cost_per_click"])
# Out:
# count   23886.000
# mean        0.402
# std         0.666
# min         0.000
# 5%          0.011
# 10%         0.023
# 25%         0.070
# 50%         0.204
# 75%         0.450
# 90%         0.947
# 95%         1.439
# 99%         3.253
# 99.5%       4.262
# max        15.728
# Name: cost_per_click, dtype: float64

# %%
# low cardinality categorical variable, let's use CategoricalSimilaritySpace!
filtered_dataset["ext_service_name"].value_counts()
# Out:
# ext_service_name
# Facebook Ads    7972
# Google Ads      7957
# DV360           7957
# Name: count, dtype: int64

# %%
filtered_dataset.head()
# Out:
#    index        time  media_cost_usd  no_of_days  \
# 0      0  1651536000         109.420           9
# 1      1  1654041600          43.151          54
# 2      2  1654128000          31.436          55
# 3      3  1654387200          13.351          58
# 4      4  1654732800          13.629          62
#
#                               search_tags                   keywords  \
# 0      #Embrace Your Individuality with X            artisan jewelry
# 1  #The Ultimate Fashion Statement with X             bridal jewelry
# 2  #The Ultimate Fashion Statement with X  unique and trendy jewelry
# 3      #Embrace Your Individuality with X            artisan jewelry
# 4      #Embrace Your Individuality with X         rhinestone jewelry
#
#   ext_service_name  clicks  daily_cost  daily_click  cost_per_click
# 0     Facebook Ads      32      12.158        3.556           3.419
# 1       Google Ads      18       0.799        0.333           2.397
# 2            DV360      12       0.572        0.218           2.620
# 3     Facebook Ads      12       0.230        0.207           1.113
# 4     Facebook Ads      10       0.220        0.161           1.363

# %% [markdown]
# ## Set up Superlinked

# %%
class Campaign(sl.Schema):
    id: sl.IdField
    start_date: sl.Timestamp
    number_of_days: sl.Integer
    creative: sl.String
    keywords: sl.String
    ext_service_name: sl.StringList
    daily_cost: sl.Float
    daily_click: sl.Float
    cost_per_click: sl.Float

# %%
campaign = Campaign()

# %%
# use parameters derived above from plots and tables
recency_space = sl.RecencySpace(
    timestamp=campaign.start_date,
    period_time_list=[
        sl.PeriodTime(timedelta(days=60)),
        sl.PeriodTime(timedelta(days=180)),
    ],
)
num_days_space = sl.NumberSpace(number=campaign.number_of_days, min_value=1, max_value=100, mode=sl.Mode.SIMILAR)
daily_cost_space = sl.NumberSpace(number=campaign.daily_cost, min_value=0, max_value=50, mode=sl.Mode.SIMILAR)
daily_click_space = sl.NumberSpace(number=campaign.daily_click, min_value=0, max_value=100, mode=sl.Mode.MAXIMUM)
cost_per_click_space = sl.NumberSpace(number=campaign.daily_click, min_value=0, max_value=2, mode=sl.Mode.MINIMUM)
service_space = sl.CategoricalSimilaritySpace(
    category_input=campaign.ext_service_name,
    categories=filtered_dataset["ext_service_name"].unique().tolist(),
    negative_filter=-5.0,
)
# textual data is simply encoded using a reasonably large and well performing model
creative_space = sl.TextSimilaritySpace(text=campaign.creative, model="sentence-transformers/all-mpnet-base-v2")
keywords_space = sl.TextSimilaritySpace(text=campaign.keywords, model="sentence-transformers/all-mpnet-base-v2")

# %%
campaign_index = sl.Index(
    spaces=[
        recency_space,
        num_days_space,
        daily_cost_space,
        daily_click_space,
        cost_per_click_space,
        service_space,
        creative_space,
        keywords_space,
    ]
)

# %%
campaign_df_parser = sl.DataFrameParser(
    schema=campaign,
    mapping={
        campaign.id: "index",
        campaign.start_date: "time",
        campaign.number_of_days: "no_of_days",
        campaign.creative: "search_tags",
    },
)

# %%
source_campaign: sl.InMemorySource = sl.InMemorySource(campaign, parser=campaign_df_parser)
executor: sl.InMemoryExecutor = sl.InMemoryExecutor(
    sources=[source_campaign], indices=[campaign_index], context_data=EXECUTOR_DATA
)
app: sl.InMemoryApp = executor.run()

# %%
source_campaign.put([filtered_dataset])

# %% [markdown]
# ## Run queries

# %%
# a query to browse campaign data without taking a specific campaign as base
# define a versatile query and simply just switch in features as we go
campaign_discovery_query = (
    sl.Query(
        campaign_index,
        weights={
            keywords_space: sl.Param("keywords_weight"),
            creative_space: sl.Param("creative_weight"),
            service_space: sl.Param("service_weight"),
            cost_per_click_space: sl.Param("cost_per_click_weight"),
            daily_cost_space: sl.Param("daily_cost_weight"),
            daily_click_space: sl.Param("daily_click_weight"),
            num_days_space: sl.Param("num_days_weight"),
            recency_space: sl.Param("recency_weight"),
        },
    )
    .find(campaign)
    .similar(num_days_space, sl.Param("target_length_in_days"))
    .similar(daily_cost_space, sl.Param("target_daily_cost"))
    .similar(creative_space, sl.Param("target_creative"))
    .similar(keywords_space, sl.Param("target_keywords"))
    .similar(service_space, sl.Param("target_service"))
    .select_all()
    .limit(sl.Param("limit"))
)

# %%
# first let's just switch the search on in terms of the text of the creative of the ad
only_search_tag_results = app.query(
    campaign_discovery_query,
    keywords_weight=0,
    creative_weight=1,
    service_weight=0,
    cost_per_click_weight=0,
    daily_cost_weight=0,
    daily_click_weight=0,
    num_days_weight=0,
    recency_weight=0,
    target_length_in_days=0.0,
    target_daily_cost=0,
    target_creative="embrace your individuality",
    target_keywords="",
    target_service="",
    limit=10,
)

# these are essentially in random order, as there are only 2 distinct creatives at the moment
df = sl.PandasConverter.to_pandas(only_search_tag_results)
sl.PandasConverter.format_date_column(df, "start_date")
# Out:
#    start_date  number_of_days                            creative  \
# 0  2022-05-02               1  #Embrace Your Individuality with X
# 1  2022-05-02               1  #Embrace Your Individuality with X
# 2  2022-05-03               2  #Embrace Your Individuality with X
# 3  2022-05-02               1  #Embrace Your Individuality with X
# 4  2022-05-11               4  #Embrace Your Individuality with X
# 5  2022-07-06               2  #Embrace Your Individuality with X
# 6  2022-08-21               2  #Embrace Your Individuality with X
# 7  2022-10-08               1  #Embrace Your Individuality with X
# 8  2022-10-01               3  #Embrace Your Individuality with X
# 9  2022-09-30               1  #Embrace Your Individuality with X
#
#                        keywords ext_service_name  daily_cost  daily_click  \
# 0             layered necklaces   [Facebook Ads]     489.513     1630.000
# 1                  body jewelry          [DV360]     396.772     1794.000
# 2              seasonal jewelry          [DV360]     198.378     1029.000
# 3     affordable trendy jewelry   [Facebook Ads]     346.197     1257.000
# 4     affordable trendy jewelry   [Facebook Ads]     257.778      799.250
# 5               initial jewelry     [Google Ads]     166.715      326.000
# 6              festival jewelry     [Google Ads]      51.151       66.000
# 7               crystal jewelry     [Google Ads]      66.336       41.000
# 8             artisanal jewelry          [DV360]      73.403     1250.000
# 9  affordable statement jewelry     [Google Ads]      87.910       62.000
#
#    cost_per_click     id  similarity_score
# 0           0.300  23169             0.074
# 1           0.221  23194             0.074
# 2           0.193  23195             0.074
# 3           0.275  23253             0.074
# 4           0.323  23382             0.074
# 5           0.511   7227             0.074
# 6           0.775  20826             0.074
# 7           1.618   5019             0.074
# 8           0.059   6770             0.074
# 9           1.418   6778             0.074

# %%
# now let's only consider campaigns on Facebook
search_tag_on_fb_result = app.query(
    campaign_discovery_query,
    keywords_weight=0,
    creative_weight=1,
    service_weight=1,
    cost_per_click_weight=0,
    daily_cost_weight=0,
    daily_click_weight=0,
    num_days_weight=0,
    recency_weight=0,
    target_length_in_days=0,
    target_daily_cost=0,
    target_creative="embrace your individuality",
    target_keywords="",
    target_service="Facebook Ads",
    limit=10,
)

df = sl.PandasConverter.to_pandas(search_tag_on_fb_result)
sl.PandasConverter.format_date_column(df, "start_date")
# Out:
#    start_date  number_of_days                            creative  \
# 0  2022-05-02               1  #Embrace Your Individuality with X
# 1  2022-05-02               1  #Embrace Your Individuality with X
# 2  2022-05-11               4  #Embrace Your Individuality with X
# 3  2022-10-02               1  #Embrace Your Individuality with X
# 4  2022-10-02               1  #Embrace Your Individuality with X
# 5  2022-10-01               3  #Embrace Your Individuality with X
# 6  2022-07-08               4  #Embrace Your Individuality with X
# 7  2022-07-06               2  #Embrace Your Individuality with X
# 8  2022-10-04               4  #Embrace Your Individuality with X
# 9  2022-10-10               9  #Embrace Your Individuality with X
#
#                     keywords ext_service_name  daily_cost  daily_click  \
# 0          layered necklaces   [Facebook Ads]     489.513     1630.000
# 1  affordable trendy jewelry   [Facebook Ads]     346.197     1257.000
# 2  affordable trendy jewelry   [Facebook Ads]     257.778      799.250
# 3          threader earrings   [Facebook Ads]     885.025     6569.000
# 4               bold jewelry   [Facebook Ads]    1094.291     8090.000
# 5             formal jewelry   [Facebook Ads]      78.958      445.667
# 6             animal jewelry   [Facebook Ads]      55.599      178.500
# 7             zodiac jewelry   [Facebook Ads]      83.082      261.000
# 8           handmade jewelry   [Facebook Ads]      83.707      338.000
# 9              beach jewelry   [Facebook Ads]     136.750      507.444
#
#    cost_per_click     id  similarity_score
# 0           0.300  23169             0.132
# 1           0.275  23253             0.132
# 2           0.323  23382             0.132
# 3           0.135  23832             0.131
# 4           0.135  23975             0.131
# 5           0.177   6006             0.131
# 6           0.311   6537             0.131
# 7           0.318   6586             0.131
# 8           0.248  23561             0.131
# 9           0.269  23835             0.131

# %%
# now let's take into account that we are looking for ~30 day campaigns
search_tag_fb_30_days_results = app.query(
    campaign_discovery_query,
    keywords_weight=0,
    creative_weight=1,
    service_weight=1,
    cost_per_click_weight=0,
    daily_cost_weight=0,
    daily_click_weight=0,
    num_days_weight=1,
    recency_weight=0,
    target_length_in_days=30.0,
    target_daily_cost=0,
    target_creative="embrace your individuality",
    target_keywords="",
    target_service="Facebook Ads",
    limit=10,
)

df = sl.PandasConverter.to_pandas(search_tag_fb_30_days_results)
sl.PandasConverter.format_date_column(df, "start_date")
# Out:
#    start_date  number_of_days                            creative  \
# 0  2022-06-11              29  #Embrace Your Individuality with X
# 1  2022-05-25              33  #Embrace Your Individuality with X
# 2  2022-06-08              26  #Embrace Your Individuality with X
# 3  2022-09-17              30  #Embrace Your Individuality with X
# 4  2022-09-16              29  #Embrace Your Individuality with X
# 5  2022-09-19              32  #Embrace Your Individuality with X
# 6  2022-09-29              28  #Embrace Your Individuality with X
# 7  2022-08-20              28  #Embrace Your Individuality with X
# 8  2022-09-15              28  #Embrace Your Individuality with X
# 9  2022-08-19              28  #Embrace Your Individuality with X
#
#                        keywords ext_service_name  daily_cost  daily_click  \
# 0                 party jewelry   [Facebook Ads]       2.859       11.862
# 1                luxury jewelry   [Facebook Ads]       0.756        2.455
# 2            minimalist jewelry   [Facebook Ads]       0.785        7.269
# 3                dainty jewelry   [Facebook Ads]       2.515        9.333
# 4  affordable statement jewelry   [Facebook Ads]       2.542       12.103
# 5                 hoop earrings   [Facebook Ads]       2.430        6.406
# 6                dainty jewelry   [Facebook Ads]       0.645        3.071
# 7  affordable statement jewelry   [Facebook Ads]       2.036        9.964
# 8                spring jewelry   [Facebook Ads]       1.266        3.250
# 9                 party jewelry   [Facebook Ads]       1.513        6.214
#
#    cost_per_click     id  similarity_score
# 0           0.241  23184             0.171
# 1           0.308  23173             0.171
# 2           0.108  23272             0.171
# 3           0.269   5906             0.170
# 4           0.210   6663             0.170
# 5           0.379   7133             0.170
# 6           0.210   5509             0.170
# 7           0.204   5824             0.170
# 8           0.390   6411             0.170
# 9           0.243   6444             0.170

# %%
# let's also factor in that we aim to spend 0.5 thousand USDs a day
search_tag_fb_30_days_daily_05_results = app.query(
    campaign_discovery_query,
    keywords_weight=0,
    creative_weight=1,
    service_weight=1,
    cost_per_click_weight=0,
    daily_cost_weight=1,
    daily_click_weight=0,
    num_days_weight=1,
    recency_weight=0,
    target_length_in_days=30.0,
    target_daily_cost=0.5,
    target_creative="embrace your individuality",
    target_keywords="",
    target_service="Facebook Ads",
    limit=10,
)

# some extremely low spending campaigns now disappeared from the top results
df = sl.PandasConverter().to_pandas(search_tag_fb_30_days_daily_05_results)
sl.PandasConverter.format_date_column(df, "start_date")
# Out:
#    start_date  number_of_days                            creative  \
# 0  2022-05-25              33  #Embrace Your Individuality with X
# 1  2022-06-08              26  #Embrace Your Individuality with X
# 2  2022-06-11              29  #Embrace Your Individuality with X
# 3  2022-09-29              28  #Embrace Your Individuality with X
# 4  2022-08-20              28  #Embrace Your Individuality with X
# 5  2022-08-23              28  #Embrace Your Individuality with X
# 6  2022-09-15              28  #Embrace Your Individuality with X
# 7  2022-08-19              28  #Embrace Your Individuality with X
# 8  2022-09-07              33  #Embrace Your Individuality with X
# 9  2022-09-15              28  #Embrace Your Individuality with X
#
#              keywords ext_service_name  daily_cost  daily_click  \
# 0      luxury jewelry   [Facebook Ads]       0.756        2.455
# 1  minimalist jewelry   [Facebook Ads]       0.785        7.269
# 2       party jewelry   [Facebook Ads]       2.859       11.862
# 3      dainty jewelry   [Facebook Ads]       0.645        3.071
# 4  rhinestone jewelry   [Facebook Ads]       0.816        2.607
# 5     charm bracelets   [Facebook Ads]       1.178        5.321
# 6      spring jewelry   [Facebook Ads]       1.266        3.250
# 7       party jewelry   [Facebook Ads]       1.513        6.214
# 8      casual jewelry   [Facebook Ads]       0.679        2.121
# 9   layered bracelets   [Facebook Ads]       1.701        7.214
#
#    cost_per_click     id  similarity_score
# 0           0.308  23173             0.204
# 1           0.108  23272             0.204
# 2           0.241  23184             0.203
# 3           0.210   5509             0.203
# 4           0.313   7415             0.203
# 5           0.221  24190             0.203
# 6           0.390   6411             0.203
# 7           0.243   6444             0.203
# 8           0.320  23919             0.203
# 9           0.236   9478             0.203

# %% [markdown]
# ### Optimize for a target
#
# Now let's also blend in that we are looking for the best campaigns within these soft filters

# %% [markdown]
# #### Clicks

# %%
# get the most clicks without regard to cost
search_click_optim_results = app.query(
    campaign_discovery_query,
    keywords_weight=0,
    creative_weight=1,
    service_weight=1,
    cost_per_click_weight=0,
    daily_cost_weight=1,
    daily_click_weight=0.1,
    num_days_weight=1,
    recency_weight=0,
    target_length_in_days=30.0,
    target_daily_cost=0.5,
    target_creative="embrace your individuality",
    target_keywords="",
    target_service="Facebook Ads",
    limit=10,
)

# high click creating campaigns are at the top - regardless of their cost
df = sl.PandasConverter().to_pandas(search_click_optim_results)
sl.PandasConverter.format_date_column(df, "start_date")
# Out:
#    start_date  number_of_days                            creative  \
# 0  2022-09-01              24  #Embrace Your Individuality with X
# 1  2022-08-30              25  #Embrace Your Individuality with X
# 2  2022-08-31              26  #Embrace Your Individuality with X
# 3  2022-09-04              17  #Embrace Your Individuality with X
# 4  2022-09-02              15  #Embrace Your Individuality with X
# 5  2022-08-31              13  #Embrace Your Individuality with X
# 6  2022-08-29              24  #Embrace Your Individuality with X
# 7  2022-09-03              16  #Embrace Your Individuality with X
# 8  2022-08-31              13  #Embrace Your Individuality with X
# 9  2022-10-16              18  #Embrace Your Individuality with X
#
#                     keywords ext_service_name  daily_cost  daily_click  \
# 0             formal jewelry   [Facebook Ads]       1.428      150.833
# 1             animal jewelry   [Facebook Ads]       3.945      342.040
# 2             bridal jewelry   [Facebook Ads]       4.718      354.462
# 3  designer-inspired jewelry   [Facebook Ads]       2.315       97.824
# 4           everyday jewelry   [Facebook Ads]       4.927      425.333
# 5             casual jewelry   [Facebook Ads]       3.030      117.615
# 6             luxury jewelry   [Facebook Ads]       5.053       51.958
# 7            concert jewelry   [Facebook Ads]       3.480       58.562
# 8           everyday jewelry   [Facebook Ads]       5.750       85.385
# 9          victorian jewelry   [Facebook Ads]       6.628       66.056
#
#    cost_per_click     id  similarity_score
# 0           0.009   5427             0.208
# 1           0.012  23932             0.208
# 2           0.013  23784             0.207
# 3           0.024  24268             0.207
# 4           0.012  23951             0.206
# 5           0.026  24266             0.206
# 6           0.097   6905             0.206
# 7           0.059  23463             0.205
# 8           0.067  23711             0.205
# 9           0.100   6776             0.205

# %%
# take it to the extreme - be more lenient with daily_cost and no_of_days thresholds
# and favor better performing campaigns
extreme_search_click_optim_results = app.query(
    campaign_discovery_query,
    keywords_weight=0,
    creative_weight=1,
    service_weight=1,
    cost_per_click_weight=0,
    daily_cost_weight=1,
    daily_click_weight=1,
    num_days_weight=1,
    recency_weight=0,
    target_length_in_days=30.0,
    target_daily_cost=0.5,
    target_creative="embrace your individuality",
    target_keywords="",
    target_service="Facebook Ads",
    limit=10,
)

# the results focus even more on the clicks the campaign was able to generate
df = sl.PandasConverter().to_pandas(extreme_search_click_optim_results)
sl.PandasConverter.format_date_column(df, "start_date")
# Out:
#    start_date  number_of_days                            creative  \
# 0  2022-09-01              24  #Embrace Your Individuality with X
# 1  2022-08-30              25  #Embrace Your Individuality with X
# 2  2022-08-31              26  #Embrace Your Individuality with X
# 3  2022-09-04              17  #Embrace Your Individuality with X
# 4  2022-09-02              15  #Embrace Your Individuality with X
# 5  2022-08-31              13  #Embrace Your Individuality with X
# 6  2022-08-29              11  #Embrace Your Individuality with X
# 7  2022-08-29              11  #Embrace Your Individuality with X
# 8  2022-08-31              13  #Embrace Your Individuality with X
# 9  2022-10-09              11  #Embrace Your Individuality with X
#
#                     keywords ext_service_name  daily_cost  daily_click  \
# 0             formal jewelry   [Facebook Ads]       1.428      150.833
# 1             animal jewelry   [Facebook Ads]       3.945      342.040
# 2             bridal jewelry   [Facebook Ads]       4.718      354.462
# 3  designer-inspired jewelry   [Facebook Ads]       2.315       97.824
# 4           everyday jewelry   [Facebook Ads]       4.927      425.333
# 5             casual jewelry   [Facebook Ads]       3.030      117.615
# 6             modern jewelry   [Facebook Ads]       6.700      170.818
# 7              stud earrings   [Facebook Ads]       6.767      128.636
# 8           everyday jewelry   [Facebook Ads]       5.750       85.385
# 9             cuff bracelets   [Facebook Ads]      13.028       87.000
#
#    cost_per_click     id  similarity_score
# 0           0.009   5427             0.211
# 1           0.012  23932             0.211
# 2           0.013  23784             0.210
# 3           0.024  24268             0.210
# 4           0.012  23951             0.209
# 5           0.026  24266             0.209
# 6           0.039  23949             0.208
# 7           0.053  24072             0.208
# 8           0.067  23711             0.208
# 9           0.150   6810             0.205

# %% [markdown]
# #### Cost

# %%
# Find the most efficient campaigns in terms of cost_per_click
search_cost_optim_results = app.query(
    campaign_discovery_query,
    keywords_weight=0,
    creative_weight=1,
    service_weight=1,
    cost_per_click_weight=1,
    daily_cost_weight=1,
    daily_click_weight=0,
    num_days_weight=1,
    recency_weight=0,
    target_length_in_days=30.0,
    target_daily_cost=0.5,
    target_creative="embrace your individuality",
    target_keywords="",
    target_service="Facebook Ads",
    limit=10,
)

df = sl.PandasConverter().to_pandas(search_cost_optim_results)
sl.PandasConverter.format_date_column(df, "start_date")
# Out:
#    start_date  number_of_days                            creative  \
# 0  2022-08-21              31  #Embrace Your Individuality with X
# 1  2022-07-22              32  #Embrace Your Individuality with X
# 2  2022-07-14              28  #Embrace Your Individuality with X
# 3  2022-07-19              33  #Embrace Your Individuality with X
# 4  2022-08-05              32  #Embrace Your Individuality with X
# 5  2022-09-19              32  #Embrace Your Individuality with X
# 6  2022-09-01              30  #Embrace Your Individuality with X
# 7  2022-08-20              30  #Embrace Your Individuality with X
# 8  2022-08-31              30  #Embrace Your Individuality with X
# 9  2022-08-26              24  #Embrace Your Individuality with X
#
#                        keywords ext_service_name  daily_cost  daily_click  \
# 0                bridal jewelry   [Facebook Ads]       0.037        0.065
# 1                 hoop earrings   [Facebook Ads]       0.005        0.062
# 2               statement rings   [Facebook Ads]       0.006        0.071
# 3           renaissance jewelry   [Facebook Ads]       0.026        0.091
# 4              colorful jewelry   [Facebook Ads]       0.046        0.125
# 5  affordable statement jewelry   [Facebook Ads]       0.009        0.125
# 6                chunky jewelry   [Facebook Ads]       0.124        0.133
# 7               baroque jewelry   [Facebook Ads]       0.038        0.133
# 8                zodiac jewelry   [Facebook Ads]       0.022        0.133
# 9                 drop earrings   [Facebook Ads]       0.020        0.083
#
#    cost_per_click     id  similarity_score
# 0           0.574  15723             0.210
# 1           0.074  20962             0.210
# 2           0.088  17259             0.210
# 3           0.281  11496             0.210
# 4           0.367  22981             0.209
# 5           0.070   7128             0.209
# 6           0.927  16796             0.209
# 7           0.283  15722             0.209
# 8           0.163   2591             0.209
# 9           0.239  16738             0.209

# %% [markdown]
# ## What we achieved
#
# Using Superlinked we were able to drill through our campaign dataset by gradually building up a collection of result sets where we are
#
# 1. softly favoring campaigns that are similar to our planned one in terms of:
#     * length,
#     * budget,
#     * the ad platform we are targeting and
#     * creative text.
# <br/><br/>
# 2. optimize for different metrics having fine-grained control over the tradeoff of relaxing our constraints, but getting better performing campaigns.
